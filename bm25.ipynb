# %%
import os
import re
import math
from collections import defaultdict

def preprocess(text):
    return re.findall(r'\b\w+\b', text.lower())

# Load documents
def load_documents(folder_path):
    docs = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8', errors='ignore') as file:
                docs[filename] = preprocess(file.read())
    return docs

# Load queries
def load_queries(query_file_path):
    with open(query_file_path, 'r', encoding='utf-8') as file:
        return [line.strip() for line in file.readlines()]

# Compute statistics needed for BM25 and LM
def compute_statistics(docs):
    doc_count = len(docs)
    doc_lengths = {}
    total_doc_length = 0
    term_freqs = defaultdict(lambda: defaultdict(int))
    doc_freqs = defaultdict(int)
    collection_freqs = defaultdict(int)
    total_collection_length = 0

    for doc_id, words in docs.items():
        length = len(words)
        doc_lengths[doc_id] = length
        total_doc_length += length
        
        # Count words in this doc
        for word in words:
            term_freqs[doc_id][word] += 1
            collection_freqs[word] += 1
            total_collection_length += 1
            
        # Count document frequency (unique words)
        for word in set(words):
            doc_freqs[word] += 1

    avgdl = total_doc_length / doc_count
    
    return term_freqs, doc_freqs, collection_freqs, doc_lengths, avgdl, total_collection_length, doc_count

# BM25 Scoring Function
def score_bm25(query, doc_id, term_freqs, doc_freqs, doc_lengths, avgdl, doc_count):
    k1 = 1.2
    b = 0.75
    score = 0.0
    doc_len = doc_lengths[doc_id]
    
    for term in query:
        if term not in doc_freqs:
            continue
            
        tf = term_freqs[doc_id].get(term, 0)
        df = doc_freqs[term]
        
        # IDF
        idf = math.log((doc_count - df + 0.5) / (df + 0.5) + 1)
        
        # BM25 term weight
        numerator = tf * (k1 + 1)
        denominator = tf + k1 * (1 - b + b * (doc_len / avgdl))
        
        score += idf * (numerator / denominator)
        
    return score

# LM-JM Scoring Function
def score_lm_jm(query, doc_id, term_freqs, collection_freqs, doc_lengths, total_collection_length):
    lam = 0.5
    score = 0.0
    doc_len = doc_lengths[doc_id]
    
    for term in query:
        # P(t|d)
        tf = term_freqs[doc_id].get(term, 0)
        p_t_d = tf / doc_len if doc_len > 0 else 0
        
        # P(t|C)
        cf = collection_freqs.get(term, 0)
        p_t_c = cf / total_collection_length if total_collection_length > 0 else 0
        
        if p_t_c == 0:
            continue
            
        prob = (1 - lam) * p_t_d + lam * p_t_c
        if prob > 0:
            score += math.log(prob)
            
    return score

# Main retrieval function
def retrieve_documents(folder_path, query_file_path):
    docs = load_documents(folder_path)
    queries = load_queries(query_file_path)
    
    term_freqs, doc_freqs, collection_freqs, doc_lengths, avgdl, total_collection_length, doc_count = compute_statistics(docs)
    
    print("Comparison of Top 5 Documents (BM25 vs LM-JM):")
    print("=" * 80)

    for query in queries:
        query_terms = preprocess(query)
        
        scores_bm25 = {}
        scores_lm = {}
        
        for doc_id in docs:
            scores_bm25[doc_id] = score_bm25(query_terms, doc_id, term_freqs, doc_freqs, doc_lengths, avgdl, doc_count)
            scores_lm[doc_id] = score_lm_jm(query_terms, doc_id, term_freqs, collection_freqs, doc_lengths, total_collection_length)
            
        ranked_bm25 = sorted(scores_bm25.items(), key=lambda item: item[1], reverse=True)
        ranked_lm = sorted(scores_lm.items(), key=lambda item: item[1], reverse=True)
        
        print(f"Query: {query}")
        print(f"{'Rank':<5} | {'BM25 Document':<20} {'Score':<10} | {'LM-JM Document':<20} {'Score':<10}")
        print("-" * 80)
        
        for i in range(5):
            doc_bm25, val_bm25 = ranked_bm25[i]
            doc_lm, val_lm = ranked_lm[i]
            print(f"{i+1:<5} | {doc_bm25:<20} {val_bm25:<10.4f} | {doc_lm:<20} {val_lm:<10.4f}")
        print("=" * 80)
        print()

# Run the code
folder_path = 'Trump Speechs'
query_file_path = 'queries1.txt'
retrieve_documents(folder_path, query_file_path)
# Out:
# Comparison of Top 5 Documents (BM25 vs LM-JM):
# ================================================================================
# Query: to
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_30.txt        0.0192     | speech_13.txt        -3.2525
# 2     | speech_3.txt         0.0192     | speech_48.txt        -3.3043
# 3     | speech_19.txt        0.0192     | speech_41.txt        -3.3043
# 4     | speech_41.txt        0.0192     | speech_30.txt        -3.3221
# 5     | speech_48.txt        0.0192     | speech_43.txt        -3.3233
# ================================================================================
#
# Query: america strong
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_2.txt         0.5943     | speech_13.txt        -11.9589
# 2     | speech_13.txt        0.5678     | speech_2.txt         -12.3390
# 3     | speech_23.txt        0.5503     | speech_46.txt        -12.5966
# 4     | speech_46.txt        0.5368     | speech_51.txt        -12.6567
# 5     | speech_49.txt        0.5361     | speech_49.txt        -12.6705
# ================================================================================
#
# Query: to bring us
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_29.txt        0.4019     | speech_3.txt         -15.9633
# 2     | speech_36.txt        0.4018     | speech_29.txt        -16.1225
# 3     | speech_0.txt         0.4002     | speech_0.txt         -16.1298
# 4     | speech_25.txt        0.3988     | speech_36.txt        -16.1368
# 5     | speech_3.txt         0.3868     | speech_16.txt        -16.1688
# ================================================================================
#
# Query: white
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_49.txt        0.8016     | speech_49.txt        -6.8838
# 2     | speech_14.txt        0.7386     | speech_14.txt        -7.1022
# 3     | speech_27.txt        0.7299     | speech_27.txt        -7.1521
# 4     | speech_24.txt        0.7089     | speech_24.txt        -7.2622
# 5     | speech_47.txt        0.6911     | speech_47.txt        -7.3472
# ================================================================================
#
# Query: future i
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_20.txt        0.6607     | speech_20.txt        -10.1768
# 2     | speech_10.txt        0.6356     | speech_11.txt        -10.2214
# 3     | speech_11.txt        0.6305     | speech_10.txt        -10.2426
# 4     | speech_12.txt        0.6305     | speech_15.txt        -10.2667
# 5     | speech_21.txt        0.6066     | speech_21.txt        -10.4727
# ================================================================================
#
# Query: new hope i
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_15.txt        1.9261     | speech_15.txt        -16.2551
# 2     | speech_53.txt        1.6768     | speech_27.txt        -17.3874
# 3     | speech_19.txt        1.5974     | speech_13.txt        -17.4035
# 4     | speech_8.txt         1.5841     | speech_8.txt         -17.4390
# 5     | speech_54.txt        1.5797     | speech_24.txt        -17.5390
# ================================================================================
#
# Query: a
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_8.txt         0.0191     | speech_51.txt        -3.9171
# 2     | speech_0.txt         0.0191     | speech_0.txt         -3.9273
# 3     | speech_6.txt         0.0190     | speech_8.txt         -3.9273
# 4     | speech_19.txt        0.0190     | speech_6.txt         -3.9336
# 5     | speech_2.txt         0.0190     | speech_53.txt        -3.9349
# ================================================================================
#
# Query: who have
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_3.txt         0.0368     | speech_22.txt        -9.6801
# 2     | speech_7.txt         0.0368     | speech_28.txt        -9.7807
# 3     | speech_22.txt        0.0367     | speech_3.txt         -9.8077
# 4     | speech_20.txt        0.0367     | speech_16.txt        -9.8750
# 5     | speech_16.txt        0.0366     | speech_7.txt         -9.9188
# ================================================================================
#
# Query: these patriotic men
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_22.txt        3.8731     | speech_22.txt        -19.7359
# 2     | speech_27.txt        3.1405     | speech_21.txt        -20.8095
# 3     | speech_21.txt        3.0989     | speech_30.txt        -21.9404
# 4     | speech_46.txt        2.6936     | speech_27.txt        -22.2330
# 5     | speech_32.txt        2.6676     | speech_32.txt        -22.5172
# ================================================================================
#
# Query: education
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_18.txt        1.1405     | speech_18.txt        -5.8205
# 2     | speech_30.txt        1.0288     | speech_43.txt        -6.5192
# 3     | speech_43.txt        1.0152     | speech_30.txt        -6.5685
# 4     | speech_19.txt        0.9735     | speech_52.txt        -6.8311
# 5     | speech_52.txt        0.9603     | speech_19.txt        -6.9115
# ================================================================================
#
# Query: bring us
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_29.txt        0.3828     | speech_0.txt         -12.4953
# 2     | speech_36.txt        0.3827     | speech_3.txt         -12.6158
# 3     | speech_0.txt         0.3811     | speech_29.txt        -12.7259
# 4     | speech_25.txt        0.3797     | speech_36.txt        -12.7384
# 5     | speech_3.txt         0.3677     | speech_16.txt        -12.8052
# ================================================================================
#
# Query: doral and they
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_8.txt         4.6089     | speech_8.txt         -16.5521
# 2     | speech_0.txt         0.1562     | speech_0.txt         -18.6234
# 3     | speech_19.txt        0.1539     | speech_44.txt        -18.9890
# 4     | speech_6.txt         0.1534     | speech_19.txt        -19.0159
# 5     | speech_44.txt        0.1528     | speech_6.txt         -19.1630
# ================================================================================
#
# Query: mike
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_6.txt         4.0088     | speech_6.txt         -6.1962
# 2     | speech_8.txt         3.9941     | speech_8.txt         -6.3193
# 3     | speech_55.txt        3.8023     | speech_55.txt        -6.3602
# 4     | speech_40.txt        3.1720     | speech_40.txt        -7.1625
# 5     | speech_45.txt        2.9506     | speech_45.txt        -7.2800
# ================================================================================
#
# Query: who have
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_3.txt         0.0368     | speech_22.txt        -9.6801
# 2     | speech_7.txt         0.0368     | speech_28.txt        -9.7807
# 3     | speech_22.txt        0.0367     | speech_3.txt         -9.8077
# 4     | speech_20.txt        0.0367     | speech_16.txt        -9.8750
# 5     | speech_16.txt        0.0366     | speech_7.txt         -9.9188
# ================================================================================
#
# Query: 40 percent an
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_31.txt        2.8020     | speech_31.txt        -19.8191
# 2     | speech_26.txt        2.4799     | speech_43.txt        -20.3675
# 3     | speech_43.txt        2.4138     | speech_14.txt        -20.7174
# 4     | speech_14.txt        2.4066     | speech_18.txt        -20.8505
# 5     | speech_8.txt         2.2408     | speech_12.txt        -20.9253
# ================================================================================
#
# Query: hillary
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_4.txt         0.1756     | speech_4.txt         -4.6591
# 2     | speech_36.txt        0.1750     | speech_36.txt        -4.6899
# 3     | speech_20.txt        0.1731     | speech_53.txt        -4.7088
# 4     | speech_54.txt        0.1728     | speech_29.txt        -4.8920
# 5     | speech_33.txt        0.1726     | speech_54.txt        -4.8943
# ================================================================================
#
# Query: make it
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_48.txt        0.1460     | speech_0.txt         -10.0051
# 2     | speech_32.txt        0.1448     | speech_10.txt        -10.2548
# 3     | speech_10.txt        0.1442     | speech_19.txt        -10.3756
# 4     | speech_45.txt        0.1441     | speech_15.txt        -10.3784
# 5     | speech_21.txt        0.1433     | speech_48.txt        -10.3901
# ================================================================================
#
# Query: jobs more than
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_26.txt        0.5439     | speech_31.txt        -16.4168
# 2     | speech_31.txt        0.5412     | speech_26.txt        -16.7292
# 3     | speech_14.txt        0.5334     | speech_14.txt        -16.8410
# 4     | speech_25.txt        0.5320     | speech_25.txt        -17.0461
# 5     | speech_29.txt        0.5316     | speech_29.txt        -17.0692
# ================================================================================
#
# Query: thriving
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_43.txt        3.2825     | speech_43.txt        -8.0629
# 2     | speech_33.txt        3.0567     | speech_33.txt        -8.2694
# 3     | speech_0.txt         2.6162     | speech_0.txt         -8.7577
# 4     | speech_1.txt         0.0000     | speech_1.txt         -11.2028
# 5     | speech_10.txt        0.0000     | speech_10.txt        -11.2028
# ================================================================================
#
# Query: come true
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_15.txt        2.0477     | speech_15.txt        -12.3638
# 2     | speech_19.txt        1.7933     | speech_19.txt        -14.0708
# 3     | speech_22.txt        1.5468     | speech_1.txt         -14.0797
# 4     | speech_46.txt        1.3016     | speech_35.txt        -14.2512
# 5     | speech_0.txt         1.3007     | speech_22.txt        -14.3206
# ================================================================================
#
# Query: a rally at
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_42.txt        1.3636     | speech_42.txt        -17.0555
# 2     | speech_27.txt        1.2482     | speech_51.txt        -17.3924
# 3     | speech_50.txt        1.2249     | speech_49.txt        -17.4148
# 4     | speech_46.txt        1.2228     | speech_46.txt        -17.4212
# 5     | speech_49.txt        1.2211     | speech_50.txt        -17.4522
# ================================================================================
#
# Query: afghanistan
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_3.txt         1.9883     | speech_3.txt         -7.9042
# 2     | speech_22.txt        1.7824     | speech_22.txt        -7.9741
# 3     | speech_41.txt        1.6359     | speech_41.txt        -8.1939
# 4     | speech_16.txt        1.6351     | speech_16.txt        -8.1951
# 5     | speech_17.txt        1.5637     | speech_17.txt        -8.2934
# ================================================================================
#
# Query: of our
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_7.txt         0.0381     | speech_38.txt        -7.6210
# 2     | speech_2.txt         0.0380     | speech_13.txt        -7.7491
# 3     | speech_26.txt        0.0380     | speech_22.txt        -7.7680
# 4     | speech_17.txt        0.0380     | speech_2.txt         -7.7724
# 5     | speech_39.txt        0.0380     | speech_7.txt         -7.7865
# ================================================================================
#
# Query: companies won t
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_48.txt        2.3978     | speech_48.txt        -19.2373
# 2     | speech_49.txt        2.2855     | speech_49.txt        -19.4315
# 3     | speech_2.txt         2.1622     | speech_6.txt         -19.6179
# 4     | speech_6.txt         2.0371     | speech_0.txt         -20.1822
# 5     | speech_45.txt        2.0238     | speech_2.txt         -20.2120
# ================================================================================
#
# Query: less
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_49.txt        1.4999     | speech_49.txt        -6.9211
# 2     | speech_48.txt        1.4532     | speech_48.txt        -7.0844
# 3     | speech_44.txt        1.3843     | speech_44.txt        -7.2879
# 4     | speech_26.txt        1.3346     | speech_26.txt        -7.4142
# 5     | speech_7.txt         1.2809     | speech_42.txt        -7.4853
# ================================================================================
#
# Query: since 1973
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_40.txt        3.3939     | speech_40.txt        -15.0017
# 2     | speech_30.txt        3.3874     | speech_30.txt        -15.2522
# 3     | speech_50.txt        0.3093     | speech_50.txt        -18.0166
# 4     | speech_41.txt        0.3028     | speech_49.txt        -18.1665
# 5     | speech_49.txt        0.3011     | speech_41.txt        -18.1890
# ================================================================================
#
# Query: ll bring back
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_0.txt         2.0662     | speech_0.txt         -18.7430
# 2     | speech_15.txt        1.9264     | speech_15.txt        -19.1179
# 3     | speech_8.txt         1.7514     | speech_46.txt        -19.4557
# 4     | speech_1.txt         1.7402     | speech_49.txt        -19.8233
# 5     | speech_6.txt         1.7308     | speech_28.txt        -19.8953
# ================================================================================
#
# Query: one
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_16.txt        0.0180     | speech_16.txt        -5.3087
# 2     | speech_11.txt        0.0178     | speech_38.txt        -5.3599
# 3     | speech_12.txt        0.0177     | speech_15.txt        -5.4314
# 4     | speech_19.txt        0.0177     | speech_14.txt        -5.4392
# 5     | speech_15.txt        0.0177     | speech_12.txt        -5.4661
# ================================================================================
#
# Query: victory and
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_27.txt        1.5363     | speech_27.txt        -10.0429
# 2     | speech_55.txt        1.3788     | speech_55.txt        -10.4593
# 3     | speech_50.txt        1.3670     | speech_50.txt        -10.6632
# 4     | speech_49.txt        1.3639     | speech_49.txt        -10.7035
# 5     | speech_47.txt        1.3122     | speech_47.txt        -10.9292
# ================================================================================
#
# Query: small handful of
# Rank  | BM25 Document        Score      | LM-JM Document       Score
# --------------------------------------------------------------------------------
# 1     | speech_44.txt        5.6708     | speech_53.txt        -18.1472
# 2     | speech_53.txt        5.1435     | speech_44.txt        -18.6364
# 3     | speech_40.txt        1.0462     | speech_14.txt        -21.5418
# 4     | speech_14.txt        0.9895     | speech_40.txt        -21.5628
# 5     | speech_52.txt        0.9794     | speech_52.txt        -21.7859
# ================================================================================
